# %% [markdown]
# # 사이파이(Scipy)를 이용한 확률 분포

# %% [markdown]
# - matplotlib 한글 설치

# %%
# !apt-get install -y fonts-nanum
# !fc-cache -fv 
# !rm -rf ~/.cache/matplotlib
# 런타임 다시 시작

# %%
import matplotlib.pyplot as mapl
import matplotlib.pyplot as plt
mapl.rcParams['axes.unicode_minus'] = False
mapl.rcParams['font.family'] = 'NanumBarunGothic'

# %% [markdown]
# -

# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt

# %%
# 기대값(평균) = 1 , 표준편차 = 2 인 정규분포 
import scipy.stats
rv = sp.stats.norm(loc=1, scale=2) # norm: 정규분포 / loc: 기댓값, scale: 표쥰편차

# %%
xx = np.linspace(-8, 8, 100)
pdf = rv.pdf(xx)
plt.plot(xx, pdf)
plt.title("확률밀도함수 ")
plt.xlabel("$x$")
plt.ylabel("$p(x)$")
plt.show()

# %% [markdown]
# - 이항분포 `sp.stats.binom(N, mu)`
#  - 시행횟수(N): 10 / 평균(mu):0.6

# %%
N = 10
mu = 0.6
rv = sp.stats.binom(N, mu)

xx = np.arange(N + 1)
plt.bar(xx, rv.pmf(xx), align="center")
plt.xlabel("표본값")
plt.ylabel("$P(x)$")
plt.title("이항분포의 확률질량함수")
plt.grid()
plt.show()

# %% [markdown]
# - 스튜던트 t 분포

# %%
xx = np.linspace(-4, 4, 100)
for df in [1, 2, 5, 10, 20]:
    rv = sp.stats.t(df=df)
    plt.plot(xx, rv.pdf(xx), label=("스튜던트 t(dof=%d)" % df))
plt.plot(xx, sp.stats.norm().pdf(xx), label="Normal", lw=5, alpha=0.5)
plt.title("자유도에 따른 스튜던트 t분포의 변화")
plt.xlabel("표본값")
plt.ylabel("p(x)")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# - 카이제곱분포 `sp.stats.chi2(df=)`

# %%
xx = np.linspace(0.01, 10, 100)
dfs = np.arange(1, 5)
lss = ["-", "--", "-.", ":"]
for df, ls in zip(dfs, lss):
    rv = sp.stats.chi2(df=df)
    plt.plot(xx, rv.pdf(xx), ls=ls, label=("자유도 %d)" % df))
plt.xlim(0, 10.1)
plt.ylim(0, 0.6)
plt.title("자유도에 따른 카이제곱분포의 변화")
plt.xlabel("표본값")
plt.ylabel("p(x)")
plt.legend()
plt.show()

# %% [markdown]
# - F 분포

# %%
xx = np.linspace(0.03, 3, 1000)
plt.plot(xx, sp.stats.f(1, 2).pdf(xx), ls="-", label="F(1,2)")
plt.plot(xx, sp.stats.f(3, 5).pdf(xx), ls="--", label="F(3,5)")
plt.plot(xx, sp.stats.f(10, 10).pdf(xx), ls="-.", label="F(10,10)")
plt.axvline(1, ls=":")
plt.xlabel("x")
plt.title("자유도에 따른 F분포의 모양")
plt.legend()
plt.show()
